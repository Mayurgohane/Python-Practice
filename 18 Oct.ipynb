# %%
import pandas as pd 
import numpy as np

# %%
a = {
    'A':[1,2,3],
    'B':[4,5,6],
    'C':[7,8,9]}

# %%
c = pd.DataFrame(a)
c
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
c.columns=['X','XX','XXX']

# %%
c
# Out:
#    X  XX  XXX
# 0  1   4    7
# 1  2   5    8
# 2  3   6    9

# %%
b = b.rename(columns={'A':'X','B':'XX','C':'XXX'})
b
# Out:
#    x  XX  XXX
# 0  1   4    7
# 1  2   5    8
# 2  3   6    9

# %%
b.set_index('x')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4976\157323871.py in ?()
# ----> 1 b.set_index('x')
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['x'] are in the columns"

# %%
c
# Out:
#    X  XX  XXX
# 0  1   4    7
# 1  2   5    8
# 2  3   6    9

# %%
c.set_index('XX')
# Out:
#     X  XXX
# XX
# 4   1    7
# 5   2    8
# 6   3    9

# %%
c.reindex()
# Out:
#    X  XX  XXX
# 0  1   4    7
# 1  2   5    8
# 2  3   6    9

# %%
c.select_dtypes(include=int)
# Out:
#    X  XX  XXX
# 0  1   4    7
# 1  2   5    8
# 2  3   6    9

# %%
a = {
    'A':[1,2.2,3],
    'B':[4,5,'Mayur'],
    'C':[7,8,9.9]}

# %%
b = pd.DataFrame(a)
b
# Out:
#      A      B    C
# 0  1.0      4  7.0
# 1  2.2      5  8.0
# 2  3.0  Mayur  9.9

# %%
b.select_dtypes(include=object)
# Out:
#        B
# 0      4
# 1      5
# 2  Mayur

# %%
b.select_dtypes(include=float)
# Out:
#      A    C
# 0  1.0  7.0
# 1  2.2  8.0
# 2  3.0  9.9

# %%
b.describe()
# Out:
#               A         C
# count  3.000000  3.000000
# mean   2.066667  8.300000
# std    1.006645  1.473092
# min    1.000000  7.000000
# 25%    1.600000  7.500000
# 50%    2.200000  8.000000
# 75%    2.600000  8.950000
# max    3.000000  9.900000

# %%
b[['A','C']].quantile(0.25)
# Out:
# A    1.6
# C    7.5
# Name: 0.25, dtype: float64

# %%
b[['A','C']].quantile(0.50)
# Out:
# A    2.2
# C    8.0
# Name: 0.5, dtype: float64

# %%
b[['A','C']].quantile(0.75)
# Out:
# A    2.60
# C    8.95
# Name: 0.75, dtype: float64

# %%
b.to_json('mayur.json')

# %%
b
# Out:
#      A      B    C
# 0  1.0      4  7.0
# 1  2.2      5  8.0
# 2  3.0  Mayur  9.9

# %%
b.loc[0:1]
# Out:
#      A  B    C
# 0  1.0  4  7.0
# 1  2.2  5  8.0

# %%
b.iloc[0:1,0:1]
# Out:
#      A
# 0  1.0

# %%
b
# Out:
#      A      B    C
# 0  1.0      4  7.0
# 1  2.2      5  8.0
# 2  3.0  Mayur  9.9

# %%
b.iloc[2:,1:2]
# Out:
#        B
# 2  Mayur

# %%
df = pd.read_csv('bank-additional-full.csv',sep=';')

# %%
df
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
df.loc[0:5]
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
# 5   45   services  married     basic.9y  unknown      no   no  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# ...

# %%
df.iloc[0:5,0:5]
# Out:
#    age        job  marital    education  default
# 0   56  housemaid  married     basic.4y       no
# 1   57   services  married  high.school  unknown
# 2   37   services  married  high.school       no
# 3   40     admin.  married     basic.6y       no
# 4   56   services  married  high.school       no

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
df.iloc[0:5,[5]]
# Out:
#   housing
# 0      no
# 1      no
# 2     yes
# 3      no
# 4      no

# %%
df.loc[0:5, 'age':'job']
# Out:
#    age        job
# 0   56  housemaid
# 1   57   services
# 2   37   services
# 3   40     admin.
# 4   56   services
# 5   45   services

# %%
df.loc[0:5, ['age','job']]
# Out:
#    age        job
# 0   56  housemaid
# 1   57   services
# 2   37   services
# 3   40     admin.
# 4   56   services
# 5   45   services

# %%
df.rename(columns={'age':'x','job':'xx'}, inplace=True)

# %%
df.head(3)
# Out:
#     x         xx  marital    education  default housing loan    contact month  \
# 0  56  housemaid  married     basic.4y       no      no   no  telephone   may
# 1  57   services  married  high.school  unknown      no   no  telephone   may
# 2  37   services  married  high.school       no     yes   no  telephone   may
#
#   day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0         mon  ...         1    999         0  nonexistent          1.1
# 1         mon  ...         1    999         0  nonexistent          1.1
# 2         mon  ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
#
# [3 rows x 21 columns]

# %%
df[['x']]
# Out:
#         x
# 0      56
# 1      57
# 2      37
# 3      40
# 4      56
# ...    ..
# 41183  73
# 41184  46
# 41185  56
# 41186  44
# 41187  74
#
# [41188 rows x 1 columns]

# %%
df.isna().sum()
# Out:
# x                 0
# xx                0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
df.isna().sum()*100
# Out:
# x                 0
# xx                0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
df.drop(['x','xx'], axis=1, inplace=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 df.drop(['x','xx'], axis=1, inplace=False)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
df
# Out:
#        marital            education  default housing loan    contact month  \
# 0      married             basic.4y       no      no   no  telephone   may
# 1      married          high.school  unknown      no   no  telephone   may
# 2      married          high.school       no     yes   no  telephone   may
# 3      married             basic.6y       no      no   no  telephone   may
# 4      married          high.school       no      no  yes  telephone   may
# ...        ...                  ...      ...     ...  ...        ...   ...
# 41183  married  professional.course       no     yes   no   cellular   nov
# 41184  married  professional.course       no      no   no   cellular   nov
# 41185  married    university.degree       no     yes   no   cellular   nov
# 41186  married  professional.course       no      no   no   cellular   nov
# 41187  married  professional.course       no     yes   no   cellular   nov
#
# ...

# %%
dff = df.copy()

# %%
dff.drop(['marital'], axis=1, inplace=True)

# %%
dff
# Out:
#                  education  default housing loan    contact month day_of_week  \
# 0                 basic.4y       no      no   no  telephone   may         mon
# 1              high.school  unknown      no   no  telephone   may         mon
# 2              high.school       no     yes   no  telephone   may         mon
# 3                 basic.6y       no      no   no  telephone   may         mon
# 4              high.school       no      no  yes  telephone   may         mon
# ...                    ...      ...     ...  ...        ...   ...         ...
# 41183  professional.course       no     yes   no   cellular   nov         fri
# 41184  professional.course       no      no   no   cellular   nov         fri
# 41185    university.degree       no     yes   no   cellular   nov         fri
# 41186  professional.course       no      no   no   cellular   nov         fri
# 41187  professional.course       no     yes   no   cellular   nov         fri
#
# ...

# %%
e = dff.copy()

# %%
dff.drop(['education'], axis=1, inplace=True)

# %%
dff.head(2)
# Out:
#    default housing loan    contact month day_of_week  duration  campaign  \
# 0       no      no   no  telephone   may         mon       261         1
# 1  unknown      no   no  telephone   may         mon       149         1
#
#    pdays  previous     poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  \
# 0    999         0  nonexistent           1.1          93.994          -36.4
# 1    999         0  nonexistent           1.1          93.994          -36.4
#
#    euribor3m  nr.employed   y
# 0      4.857       5191.0  no
# 1      4.857       5191.0  no

# %%
e.head(2)
# Out:
#      education  default housing loan    contact month day_of_week  duration  \
# 0     basic.4y       no      no   no  telephone   may         mon       261
# 1  high.school  unknown      no   no  telephone   may         mon       149
#
#    campaign  pdays  previous     poutcome  emp.var.rate  cons.price.idx  \
# 0         1    999         0  nonexistent           1.1          93.994
# 1         1    999         0  nonexistent           1.1          93.994
#
#    cons.conf.idx  euribor3m  nr.employed   y
# 0          -36.4      4.857       5191.0  no
# 1          -36.4      4.857       5191.0  no

# %%
a = pd.read_csv('bank-additional-full.csv', sep=';')
a.head(2)
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
#
# [2 rows x 21 columns]

# %%
a['age'].std()
# Out:
# 10.421249980934048

# %%
a['age'].var()
# Out:
# 108.60245116511788

# %%
a.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
pd.crosstab(a['age'],a['job'])
# Out:
# job  admin.  blue-collar  entrepreneur  housemaid  management  retired  \
# age
# 17        0            0             0          0           0        0
# 18        0            0             0          0           0        0
# 19        0            0             0          0           0        0
# 20        1            7             4          0           0        0
# 21       12           15             0          1           1        0
# ..      ...          ...           ...        ...         ...      ...
# 91        0            0             0          0           0        2
# 92        0            0             0          0           0        4
# 94        0            0             0          0           0        1
# 95        0            0             0          0           0        1
# 98        0            0             0          0           0        2
#
# job  self-employed  services  student  technician  unemployed  unknown
# age
# ...

# %%
pd.crosstab(a['age'],a['job'])
# Out:
# job  admin.  blue-collar  entrepreneur  housemaid  management  retired  \
# age
# 17        0            0             0          0           0        0
# 18        0            0             0          0           0        0
# 19        0            0             0          0           0        0
# 20        1            7             4          0           0        0
# 21       12           15             0          1           1        0
# ..      ...          ...           ...        ...         ...      ...
# 91        0            0             0          0           0        2
# 92        0            0             0          0           0        4
# 94        0            0             0          0           0        1
# 95        0            0             0          0           0        1
# 98        0            0             0          0           0        2
#
# job  self-employed  services  student  technician  unemployed  unknown
# age
# ...

# %%
a['age'].value_counts()
# Out:
# age
# 31    1947
# 32    1846
# 33    1833
# 36    1780
# 35    1759
#       ...
# 89       2
# 91       2
# 94       1
# 87       1
# 95       1
# Name: count, Length: 78, dtype: int64

# %%
a.rename({'housemaid':'Mayur'}, axis=1, inplace=True)

# %%
a.head(5)
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
a.rename({'services':55}, axis=1, inplace=True)

# %%
a
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
a.rename({'retired':55}, axis=1, inplace=True)

# %%
if 'retired' in a.columns:
    a.rename({'retired':'Mayur'},axis=1, inplace=True)
else:
    print('not found')
# Out:
# not found

# %%
a['job'].replace({'retired':'Mayur'}, inplace=True)
# Out:
# C:\Users\LEGION\AppData\Local\Temp\ipykernel_4976\1373524050.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   a['job'].replace({'retired':'Mayur'}, inplace=True)

# %%
a
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73        Mayur  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56        Mayur  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74        Mayur  married  professional.course       no     yes   no
#
# ...

# %%
a['job'].unique()
# Out:
# array(['housemaid', 'services', 'admin.', 'blue-collar', 'technician',
#        'Mayur', 'management', 'unemployed', 'self-employed', 'unknown',
#        'entrepreneur', 'student'], dtype=object)

# %%
a['job'].nunique()
# Out:
# 12

# %%
a.reset_index(drop=True, inplace=True)

# %%
a.sort_index(ascending=True, inplace=True)

# %%
a
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73        Mayur  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56        Mayur  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74        Mayur  married  professional.course       no     yes   no
#
# ...

# %%
a.sort_values('job')
# Out:
#        age      job   marital            education  default housing loan  \
# 41187   74    Mayur   married  professional.course       no     yes   no
# 18539   60    Mayur   married             basic.6y  unknown      no   no
# 3578    59    Mayur  divorced             basic.4y       no     yes   no
# 38415   88    Mayur  divorced             basic.4y       no      no   no
# 27875   75    Mayur  divorced             basic.9y       no      no   no
# ...    ...      ...       ...                  ...      ...     ...  ...
# 11977   33  unknown   married              unknown  unknown     yes   no
# 38086   69  unknown   married    university.degree       no     yes  yes
# 3207    45  unknown   married              unknown       no      no  yes
# 6407    45  unknown   married              unknown  unknown      no   no
# 7938    53  unknown   married          high.school  unknown      no   no
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# ...

# %%
a.sort_values(['age','job'])
# Out:
#        age      job   marital education  default  housing     loan   contact  \
# 37140   17  student    single   unknown       no      yes       no  cellular
# 37539   17  student    single  basic.9y       no      yes       no  cellular
# 37558   17  student    single  basic.9y       no      yes       no  cellular
# 37579   17  student    single  basic.9y       no  unknown  unknown  cellular
# 38274   17  student    single   unknown       no       no      yes  cellular
# ...    ...      ...       ...       ...      ...      ...      ...       ...
# 40469   92    Mayur   married   unknown       no       no      yes  cellular
# 38921   94    Mayur   married  basic.9y       no       no       no  cellular
# 27826   95    Mayur  divorced  basic.6y       no       no       no  cellular
# 38452   98    Mayur   married  basic.4y  unknown      yes       no  cellular
# 38455   98    Mayur   married  basic.4y  unknown      yes       no  cellular
#
# ...

# %%
a.set_index('age')
# Out:
#              job  marital            education  default housing loan  \
# age
# 56     housemaid  married             basic.4y       no      no   no
# 57      services  married          high.school  unknown      no   no
# 37      services  married          high.school       no     yes   no
# 40        admin.  married             basic.6y       no      no   no
# 56      services  married          high.school       no      no  yes
# ..           ...      ...                  ...      ...     ...  ...
# 73         Mayur  married  professional.course       no     yes   no
# 46   blue-collar  married  professional.course       no      no   no
# 56         Mayur  married    university.degree       no     yes   no
# 44    technician  married  professional.course       no      no   no
# 74         Mayur  married  professional.course       no     yes   no
#
#        contact month day_of_week  duration  campaign  pdays  previous  \
# age
# ...

# %%
a['job'].replace({'Mayur':'XXX'}, inplace=True)
# Out:
# C:\Users\LEGION\AppData\Local\Temp\ipykernel_4976\3792736552.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   a['job'].replace({'Mayur':'XXX'}, inplace=True)

# %%
a
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73          XXX  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56          XXX  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74          XXX  married  professional.course       no     yes   no
#
# ...

# %%
a.groupby('age').first()
# Out:
#               job   marital          education  default housing loan  \
# age
# 17        student    single            unknown       no     yes   no
# 18        student    single        high.school       no      no   no
# 19        student    single           basic.9y  unknown     yes   no
# 20   entrepreneur    single        high.school       no      no   no
# 21         admin.    single           basic.9y       no     yes  yes
# ..            ...       ...                ...      ...     ...  ...
# 91            XXX   married  university.degree       no     yes  yes
# 92            XXX   married            unknown       no     yes   no
# 94            XXX   married           basic.9y       no      no   no
# 95            XXX  divorced           basic.6y       no      no   no
# 98            XXX   married           basic.4y  unknown     yes   no
#
#        contact month day_of_week  duration  campaign  pdays  previous  \
# age
# ...

# %%
a.groupby('marital').get_group('married')
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73          XXX  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56          XXX  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74          XXX  married  professional.course       no     yes   no
#
# ...

# %%
a.groupby('marital').get_group('single')
# Out:
#        age          job marital            education  default housing loan  \
# 8       24   technician  single  professional.course       no     yes   no
# 9       25     services  single          high.school       no     yes   no
# 11      25     services  single          high.school       no     yes   no
# 12      29  blue-collar  single          high.school       no      no  yes
# 19      39   management  single             basic.9y  unknown      no   no
# ...    ...          ...     ...                  ...      ...     ...  ...
# 41155   31    housemaid  single    university.degree       no      no   no
# 41157   31    housemaid  single    university.degree       no      no   no
# 41172   31       admin.  single    university.degree       no     yes   no
# 41175   34      student  single              unknown       no     yes   no
# 41182   29   unemployed  single             basic.4y       no     yes   no
#
# ...

# %%
a.groupby(['job', 'marital']).get_group(("single"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[170], line 1
# ----> 1 a.groupby(['job', 'marital']).get_group(("single"))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:1112, in BaseGroupBy.get_group(self, name, obj)
#    1102     elif not isinstance(name, tuple):
#    1103         warnings.warn(
#    1104             "When grouping with a length-1 list-like, "
#    1105             "you will need to pass a length-1 tuple to get_group in a future "
#    (...)
#    1109             stacklevel=find_stack_level(),
#    1110         )
# -> 1112 inds = self._get_index(name)
#    1113 if not len(inds):
#    1114     raise KeyError(name)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:964, in BaseGroupBy._get_index(self, name)
#     959 @final
# ...

# %%
a.groupby('marital')['education'].max()
# Out:
# marital
# divorced    unknown
# married     unknown
# single      unknown
# unknown     unknown
# Name: education, dtype: object

# %%
a.groupby('marital')['education'].min()
# Out:
# marital
# divorced    basic.4y
# married     basic.4y
# single      basic.4y
# unknown     basic.4y
# Name: education, dtype: object

# %%
a.groupby('marital')['education'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# ...

# %%
a.loc[a['age']==31]
# Out:
#        age          job   marital            education  default housing loan  \
# 85      31       admin.  divorced          high.school       no      no   no
# 127     31   technician  divorced  professional.course       no     yes  yes
# 267     31      student    single    university.degree  unknown      no   no
# 291     31       admin.   married          high.school       no     yes  yes
# 402     31  blue-collar   married          high.school  unknown     yes   no
# ...    ...          ...       ...                  ...      ...     ...  ...
# 41130   31       admin.    single    university.degree       no     yes   no
# 41139   31     services   married          high.school       no     yes   no
# 41155   31    housemaid    single    university.degree       no      no   no
# 41157   31    housemaid    single    university.degree       no      no   no
# 41172   31       admin.    single    university.degree       no     yes   no
#
# ...

# %%
a.loc[a['job']=='services']
# Out:
#        age       job   marital          education  default  housing     loan  \
# 1       57  services   married        high.school  unknown       no       no
# 2       37  services   married        high.school       no      yes       no
# 4       56  services   married        high.school       no       no      yes
# 5       45  services   married           basic.9y  unknown       no       no
# 9       25  services    single        high.school       no      yes       no
# ...    ...       ...       ...                ...      ...      ...      ...
# 41079   51  services   married        high.school       no      yes       no
# 41096   28  services   married        high.school       no      yes       no
# 41115   42  services  divorced  university.degree       no  unknown  unknown
# 41139   31  services   married        high.school       no      yes       no
# 41169   62  services   married        high.school       no      yes       no
#
# ...

# %%
a.loc[a['job']=='services']
# Out:
#        age       job   marital          education  default  housing     loan  \
# 1       57  services   married        high.school  unknown       no       no
# 2       37  services   married        high.school       no      yes       no
# 4       56  services   married        high.school       no       no      yes
# 5       45  services   married           basic.9y  unknown       no       no
# 9       25  services    single        high.school       no      yes       no
# ...    ...       ...       ...                ...      ...      ...      ...
# 41079   51  services   married        high.school       no      yes       no
# 41096   28  services   married        high.school       no      yes       no
# 41115   42  services  divorced  university.degree       no  unknown  unknown
# 41139   31  services   married        high.school       no      yes       no
# 41169   62  services   married        high.school       no      yes       no
#
# ...

# %%
a['age']=a['age'].apply(lambda x: x*x)

# %%
a
# Out:
#         age          job  marital            education  default housing loan  \
# 0      3136    housemaid  married             basic.4y       no      no   no
# 1      3249     services  married          high.school  unknown      no   no
# 2      1369     services  married          high.school       no     yes   no
# 3      1600       admin.  married             basic.6y       no      no   no
# 4      3136     services  married          high.school       no      no  yes
# ...     ...          ...      ...                  ...      ...     ...  ...
# 41183  5329          XXX  married  professional.course       no     yes   no
# 41184  2116  blue-collar  married  professional.course       no      no   no
# 41185  3136          XXX  married    university.degree       no     yes   no
# 41186  1936   technician  married  professional.course       no      no   no
# 41187  5476          XXX  married  professional.course       no     yes   no
#
# ...

# %%
def add(x):
    if isinstance(x,int):
        return x+ 5

# %%
a.applymap(add)
# Out:
# C:\Users\LEGION\AppData\Local\Temp\ipykernel_4976\2776559221.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   a.applymap(add)
#         age   job marital education default housing  loan contact month  \
# 0      3141  None    None      None    None    None  None    None  None
# 1      3254  None    None      None    None    None  None    None  None
# 2      1374  None    None      None    None    None  None    None  None
# 3      1605  None    None      None    None    None  None    None  None
# 4      3141  None    None      None    None    None  None    None  None
# ...     ...   ...     ...       ...     ...     ...   ...     ...   ...
# 41183  5334  None    None      None    None    None  None    None  None
# 41184  2121  None    None      None    None    None  None    None  None
# 41185  3141  None    None      None    None    None  None    None  None
# 41186  1941  None    None      None    None    None  None    None  None
# ...
